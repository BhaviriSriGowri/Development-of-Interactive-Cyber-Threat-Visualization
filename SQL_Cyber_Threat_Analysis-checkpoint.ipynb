# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavana-katari/Development-of-Interactive-Cyber-Threat-Visualization-Dashboard/blob/main/SQL_Cyber_Threat_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SQL Task – Cyber Threat Data Analysis
#
# This notebook demonstrates the use of SQL queries on a cybersecurity threat dataset.
# The dataset was generated using AI prompting and analyzed using SQL via SQLite in Google Colab.
# All SQL operations are performed based on structured prompts.

# %% [markdown]
# ## Prompt Used for SQL Environment Setup
#
# "Set up an SQL environment in Google Colab using SQLite to perform SQL queries on a cybersecurity dataset."

# %%
import sqlite3
import pandas as pd

# %% [markdown]
# ## Prompt Used for Loading Dataset into SQL
#
# "Load the cybersecurity CSV dataset into a SQL database table for querying."

# %%
# Load CSV
df = pd.read_csv("cybersecurity_attacks.csv")

# Create SQLite database
conn = sqlite3.connect("cyber_threats.db")

# Load DataFrame into SQL table
df.to_sql("cyber_threats", conn, if_exists="replace", index=False)

print("Dataset loaded into SQLite database.")
# Out:
# Dataset loaded into SQLite database.

# %% [markdown]
# ## Prompt Used for Table Verification
#
# "Verify that the cybersecurity table has been successfully created in the SQL database."

# %%
query = "SELECT * FROM cyber_threats LIMIT 5;"
pd.read_sql(query, conn)
# Out:
#              Timestamp Source IP Address Destination IP Address  Source Port  \
# 0  2023-05-30 06:33:58     103.216.15.12           84.9.164.252        31225
# 1  2020-08-26 07:08:30    78.199.217.198         66.191.137.154        17245
# 2  2022-11-13 08:23:25      63.79.210.48          198.219.82.17        16811
# 3  2023-07-02 10:38:46     163.42.196.10        101.228.192.255        20018
# 4  2023-07-16 13:11:07     71.166.185.76        189.243.174.238         6131
#
#    Destination Port Protocol  Packet Length Packet Type Traffic Type  \
# 0             17616     ICMP            503        Data         HTTP
# 1             48166     ICMP           1174        Data         HTTP
# 2             53600      UDP            306     Control         HTTP
# 3             32534      UDP            385        Data         HTTP
# 4             26646      TCP           1462        Data          DNS
#
#                                         Payload Data  ... Action Taken  \
# 0  Qui natus odio asperiores nam. Optio nobis ius...  ...       Logged
# 1  Aperiam quos modi officiis veritatis rem. Omni...  ...      Blocked
# 2  Perferendis sapiente vitae soluta. Hic delectu...  ...      Ignored
# 3  Totam maxime beatae expedita explicabo porro l...  ...      Blocked
# 4  Odit nesciunt dolorem nisi iste iusto. Animi v...  ...      Blocked
#
#    Severity Level User Information  \
# 0             Low    Reyansh Dugal
# 1             Low       Sumer Rana
# 2             Low     Himmat Karpe
# 3          Medium       Fateh Kibe
# 4             Low     Dhanush Chad
#
#                                   Device Information Network Segment  \
# 0  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...       Segment A
# 1  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...       Segment B
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...       Segment C
# 3  Mozilla/5.0 (Macintosh; PPC Mac OS X 10_11_5; ...       Segment B
# 4  Mozilla/5.0 (compatible; MSIE 5.0; Windows NT ...       Segment C
#
#     Geo-location Data Proxy Information Firewall Logs IDS/IPS Alerts  \
# 0  Jamshedpur, Sikkim      150.9.97.135      Log Data           None
# 1  Bilaspur, Nagaland              None      Log Data           None
# 2   Bokaro, Rajasthan    114.133.48.179      Log Data     Alert Data
# 3  Jaunpur, Rajasthan              None          None     Alert Data
# 4  Anantapur, Tripura     149.6.110.119          None     Alert Data
#
#   Log Source
# 0     Server
# 1   Firewall
# 2   Firewall
# 3   Firewall
# 4   Firewall
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Prompt Used for Basic Data Retrieval
#
# "Retrieve all cyber attack records from the database."

# %%
query = "SELECT * FROM cyber_threats;"
pd.read_sql(query, conn).head()
# Out:
#              Timestamp Source IP Address Destination IP Address  Source Port  \
# 0  2023-05-30 06:33:58     103.216.15.12           84.9.164.252        31225
# 1  2020-08-26 07:08:30    78.199.217.198         66.191.137.154        17245
# 2  2022-11-13 08:23:25      63.79.210.48          198.219.82.17        16811
# 3  2023-07-02 10:38:46     163.42.196.10        101.228.192.255        20018
# 4  2023-07-16 13:11:07     71.166.185.76        189.243.174.238         6131
#
#    Destination Port Protocol  Packet Length Packet Type Traffic Type  \
# 0             17616     ICMP            503        Data         HTTP
# 1             48166     ICMP           1174        Data         HTTP
# 2             53600      UDP            306     Control         HTTP
# 3             32534      UDP            385        Data         HTTP
# 4             26646      TCP           1462        Data          DNS
#
#                                         Payload Data  ... Action Taken  \
# 0  Qui natus odio asperiores nam. Optio nobis ius...  ...       Logged
# 1  Aperiam quos modi officiis veritatis rem. Omni...  ...      Blocked
# 2  Perferendis sapiente vitae soluta. Hic delectu...  ...      Ignored
# 3  Totam maxime beatae expedita explicabo porro l...  ...      Blocked
# 4  Odit nesciunt dolorem nisi iste iusto. Animi v...  ...      Blocked
#
#    Severity Level User Information  \
# 0             Low    Reyansh Dugal
# 1             Low       Sumer Rana
# 2             Low     Himmat Karpe
# 3          Medium       Fateh Kibe
# 4             Low     Dhanush Chad
#
#                                   Device Information Network Segment  \
# 0  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...       Segment A
# 1  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...       Segment B
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...       Segment C
# 3  Mozilla/5.0 (Macintosh; PPC Mac OS X 10_11_5; ...       Segment B
# 4  Mozilla/5.0 (compatible; MSIE 5.0; Windows NT ...       Segment C
#
#     Geo-location Data Proxy Information Firewall Logs IDS/IPS Alerts  \
# 0  Jamshedpur, Sikkim      150.9.97.135      Log Data           None
# 1  Bilaspur, Nagaland              None      Log Data           None
# 2   Bokaro, Rajasthan    114.133.48.179      Log Data     Alert Data
# 3  Jaunpur, Rajasthan              None          None     Alert Data
# 4  Anantapur, Tripura     149.6.110.119          None     Alert Data
#
#   Log Source
# 0     Server
# 1   Firewall
# 2   Firewall
# 3   Firewall
# 4   Firewall
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Prompt Used for Counting Records
#
# "Count the total number of cyber attack incidents recorded in the dataset."

# %%
query = "SELECT COUNT(*) AS total_attacks FROM cyber_threats;"
pd.read_sql(query, conn)
# Out:
#    total_attacks
# 0          40000

# %% [markdown]
# ## Prompt Used for Attack Type Distribution
#
# "Analyze the number of cyber attacks grouped by attack type."

# %%
query = """
SELECT "Traffic Type" AS attack_type, COUNT(*) AS attack_count
FROM cyber_threats
GROUP BY "Traffic Type"
ORDER BY attack_count DESC;
"""
pd.read_sql(query, conn)
# Out:
#   attack_type  attack_count
# 0         DNS         13376
# 1        HTTP         13360
# 2         FTP         13264

# %% [markdown]
# ## Prompt Used for Severity-Based Analysis
#
# "Analyze the number of cyber attacks based on severity levels."

# %%
query = """
SELECT "Severity Level" AS severity, COUNT(*) AS count
FROM cyber_threats
GROUP BY "Severity Level";
"""
pd.read_sql(query, conn)
# Out:
#   severity  count
# 0     High  13382
# 1      Low  13183
# 2   Medium  13435

# %% [markdown]
# ## Prompt Used for High Severity Attack Analysis
#
# "Retrieve all cyber attacks classified as High severity."

# %%
query = """
SELECT *
FROM cyber_threats
WHERE "Severity Level" = 'High';
"""
pd.read_sql(query, conn).head()
# Out:
#              Timestamp Source IP Address Destination IP Address  Source Port  \
# 0  2022-05-16 17:55:43     97.253.103.59           77.16.101.53        26562
# 1  2023-02-12 07:13:17      11.48.99.245         178.157.14.116        34489
# 2  2023-06-27 11:02:56     49.32.208.167           72.202.237.9        56296
# 3  2023-02-01 13:17:17    54.163.130.178         62.112.149.214        47795
# 4  2023-04-18 16:46:46     4.255.187.165        136.159.186.239        39934
#
#    Destination Port Protocol  Packet Length Packet Type Traffic Type  \
# 0             17416      TCP            379        Data          DNS
# 1             20396     ICMP           1022        Data          DNS
# 2             20857      TCP           1281     Control          FTP
# 3             35243      UDP            913        Data          DNS
# 4              5259      TCP            838     Control         HTTP
#
#                                         Payload Data  ... Action Taken  \
# 0  Qui numquam inventore repellat ratione fugit o...  ...      Ignored
# 1  Amet libero optio quidem praesentium libero. E...  ...       Logged
# 2  Veritatis nihil amet atque molestias aperiam m...  ...      Blocked
# 3  Sit doloremque explicabo. Cupiditate placeat e...  ...       Logged
# 4  Sed facere culpa aliquam. Adipisci error quisq...  ...      Ignored
#
#    Severity Level User Information  \
# 0            High     Ehsaan Dalal
# 1            High     Yuvaan Dubey
# 2            High       Zaina Iyer
# 3            High    Inaaya  Soman
# 4            High    Samarth Ratti
#
#                                   Device Information Network Segment  \
# 0  Opera/9.24.(X11; Linux i686; fa-IR) Presto/2.9...       Segment A
# 1  Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_7_6...       Segment A
# 2  Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_5_8...       Segment B
# 3  Mozilla/5.0 (X11; Linux i686; rv:1.9.7.20) Gec...       Segment B
# 4  Opera/8.72.(Windows NT 6.1; ia-FR) Presto/2.9....       Segment B
#
#           Geo-location Data Proxy Information Firewall Logs IDS/IPS Alerts  \
# 0            Eluru, Manipur              None      Log Data           None
# 1  Phagwara, Andhra Pradesh      192.31.159.5      Log Data     Alert Data
# 2           Ambala, Tripura              None      Log Data     Alert Data
# 3      Silchar, Maharashtra    155.121.88.187          None           None
# 4        Solapur, Telangana              None      Log Data           None
#
#   Log Source
# 0     Server
# 1   Firewall
# 2     Server
# 3   Firewall
# 4     Server
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Prompt Used for Country-Based Attack Analysis
#
# "Analyze cyber attacks based on source country."

# %%
query = """
SELECT "Geo-location Data" AS source_country, COUNT(*) AS total_attacks
FROM cyber_threats
GROUP BY "Geo-location Data"
ORDER BY total_attacks DESC;
"""
pd.read_sql(query, conn)
# Out:
#                       source_country  total_attacks
# 0               Ghaziabad, Meghalaya             16
# 1         Kalyan-Dombivli, Jharkhand             15
# 2             Ghaziabad, Uttarakhand             14
# 3                 Ghaziabad, Tripura             14
# 4     Yamunanagar, Arunachal Pradesh             13
# ...                              ...            ...
# 8718               Ahmedabad, Odisha              1
# 8719                    Agra, Sikkim              1
# 8720             Agartala, Rajasthan              1
# 8721                Agartala, Odisha              1
# 8722                Adoni, Meghalaya              1
#
# [8723 rows x 2 columns]

# %% [markdown]
# ## Prompt Used for Device Impact Analysis
#
# "Identify the most frequently affected devices in cyber attacks."

# %%
query = """
SELECT "Device Information" AS device_affected, COUNT(*) AS attack_count
FROM cyber_threats
GROUP BY "Device Information"
ORDER BY attack_count DESC;
"""
pd.read_sql(query, conn)
# Out:
#                                          device_affected  attack_count
# 0      Mozilla/5.0 (compatible; MSIE 6.0; Windows NT ...            35
# 1      Mozilla/5.0 (compatible; MSIE 5.0; Windows 98;...            34
# 2      Mozilla/5.0 (compatible; MSIE 6.0; Windows CE;...            33
# 3      Mozilla/5.0 (compatible; MSIE 7.0; Windows NT ...            31
# 4      Mozilla/5.0 (compatible; MSIE 5.0; Windows NT ...            31
# ...                                                  ...           ...
# 32099  Mozilla/5.0 (Android 1.0; Mobile; rv:42.0) Gec...             1
# 32100  Mozilla/5.0 (Android 1.0; Mobile; rv:40.0) Gec...             1
# 32101  Mozilla/5.0 (Android 1.0; Mobile; rv:37.0) Gec...             1
# 32102  Mozilla/5.0 (Android 1.0; Mobile; rv:19.0) Gec...             1
# 32103  Mozilla/5.0 (Android 1.0; Mobile; rv:14.0) Gec...             1
#
# [32104 rows x 2 columns]

# %% [markdown]
# ## Prompt Used for Attack Outcome Analysis
#
# "Analyze the number of successful versus blocked cyber attacks."

# %%
query = """
SELECT "Action Taken" AS status, COUNT(*) AS count
FROM cyber_threats
GROUP BY "Action Taken";
"""
pd.read_sql(query, conn)
# Out:
#     status  count
# 0  Blocked  13529
# 1  Ignored  13276
# 2   Logged  13195

# %% [markdown]
# ## Prompt Used for Target System Analysis
#
# "Identify the top targeted systems based on cyber attack frequency."

# %%
query = """
SELECT "Destination IP Address" AS target_system, COUNT(*) AS count
FROM cyber_threats
GROUP BY "Destination IP Address"
ORDER BY count DESC
LIMIT 10;
"""
pd.read_sql(query, conn)
# Out:
#    target_system  count
# 0   99.98.160.72      1
# 1    99.95.228.9      1
# 2  99.93.133.112      1
# 3  99.93.108.167      1
# 4   99.92.68.119      1
# 5    99.92.28.82      1
# 6   99.90.138.12      1
# 7   99.90.126.98      1
# 8    99.9.74.231      1
# 9   99.89.175.16      1

# %% [markdown]
# ## Prompt Used for Average Severity Impact
#
# "Calculate the average impact level of cyber attacks."

# %%
query = """
SELECT AVG(
    CASE "Severity Level"
        WHEN 'Low' THEN 1
        WHEN 'Medium' THEN 2
        WHEN 'High' THEN 3
        WHEN 'Critical' THEN 4
    END
) AS avg_impact
FROM cyber_threats;
"""
pd.read_sql(query, conn)
# Out:
#    avg_impact
# 0    2.004975

# %% [markdown]
# ### Explanation
#
# The average impact level initially returned 0.0 because the `impact_level` column contained
# categorical text values rather than numeric data.
# SQL aggregate functions such as AVG require numeric input.
# To resolve this, the impact levels were mapped to numeric values and reloaded into the database,
# allowing accurate calculation of the average impact level.

# %%
query = "PRAGMA table_info(cyber_threats);"
pd.read_sql(query, conn)
# Out:
#     cid                    name     type  notnull dflt_value  pk
# 0     0               Timestamp     TEXT        0       None   0
# 1     1       Source IP Address     TEXT        0       None   0
# 2     2  Destination IP Address     TEXT        0       None   0
# 3     3             Source Port  INTEGER        0       None   0
# 4     4        Destination Port  INTEGER        0       None   0
# 5     5                Protocol     TEXT        0       None   0
# 6     6           Packet Length  INTEGER        0       None   0
# 7     7             Packet Type     TEXT        0       None   0
# 8     8            Traffic Type     TEXT        0       None   0
# 9     9            Payload Data     TEXT        0       None   0
# 10   10      Malware Indicators     TEXT        0       None   0
# 11   11          Anomaly Scores     REAL        0       None   0
# 12   12         Alerts/Warnings     TEXT        0       None   0
# 13   13             Attack Type     TEXT        0       None   0
# 14   14        Attack Signature     TEXT        0       None   0
# 15   15            Action Taken     TEXT        0       None   0
# 16   16          Severity Level     TEXT        0       None   0
# 17   17        User Information     TEXT        0       None   0
# 18   18      Device Information     TEXT        0       None   0
# 19   19         Network Segment     TEXT        0       None   0
# 20   20       Geo-location Data     TEXT        0       None   0
# 21   21       Proxy Information     TEXT        0       None   0
# 22   22           Firewall Logs     TEXT        0       None   0
# 23   23          IDS/IPS Alerts     TEXT        0       None   0
# 24   24              Log Source     TEXT        0       None   0

# %%
df = pd.read_sql("SELECT * FROM cyber_threats;", conn)
df["Severity Level"].unique()
# Out:
# array(['Low', 'Medium', 'High'], dtype=object)

# %%
impact_mapping = {
    "Low": 1,
    "Medium": 2,
    "High": 3,
    "Critical": 4
}

# %%
df["impact_level_numeric"] = df["Severity Level"].map(impact_mapping)
df.to_sql("cyber_threats", conn, if_exists="replace", index=False)
# Out:
# 40000

# %%
query = """
SELECT AVG(impact_level_numeric) AS avg_impact
FROM cyber_threats;
"""
pd.read_sql(query, conn)
# Out:
#    avg_impact
# 0    2.004975

# %% [markdown]
# ## Prompt Used for Advanced SQL Analysis
#
# "Retrieve attack types that have a higher than average impact level."

# %%
query = """
SELECT "Traffic Type" AS attack_type, AVG(impact_level_numeric) AS avg_impact
FROM cyber_threats
GROUP BY "Traffic Type"
HAVING AVG(impact_level_numeric) > (
    SELECT AVG(impact_level_numeric) FROM cyber_threats
);
"""
pd.read_sql(query, conn)
# Out:
#   attack_type  avg_impact
# 0         FTP    2.006333
# 1        HTTP    2.005763

# %% [markdown]
# ## Prompt Used for Frequent Attack Analysis
#
# "Identify the top 5 most frequent cyber attack types in the dataset."

# %%
query = """
SELECT "Traffic Type" AS attack_type, COUNT(*) AS total_attacks
FROM cyber_threats
GROUP BY "Traffic Type"
ORDER BY total_attacks DESC
LIMIT 5;
"""
pd.read_sql(query, conn)
# Out:
#   attack_type  total_attacks
# 0         DNS          13376
# 1        HTTP          13360
# 2         FTP          13264

# %% [markdown]
# ## Prompt Used for High Severity Country Analysis
#
# "Identify countries with the highest number of high severity cyber attacks."

# %%
query = """
SELECT "Geo-location Data" AS source_country, COUNT(*) AS high_severity_attacks
FROM cyber_threats
WHERE "Severity Level" = 'High'
GROUP BY "Geo-location Data"
ORDER BY high_severity_attacks DESC;
"""
pd.read_sql(query, conn)
# Out:
#                           source_country  high_severity_attacks
# 0                 Ghaziabad, Uttarakhand                      8
# 1     Thiruvananthapuram, Andhra Pradesh                      7
# 2                 Rajpur Sonarpur, Assam                      7
# 3                       Raichur, Manipur                      7
# 4                        Panihati, Assam                      7
# ...                                  ...                    ...
# 6878                    Adoni, Telangana                      1
# 6879                       Adoni, Sikkim                      1
# 6880                      Adoni, Mizoram                      1
# 6881                  Adoni, Maharashtra                      1
# 6882                    Adoni, Karnataka                      1
#
# [6883 rows x 2 columns]

# %% [markdown]
# ## Prompt Used for Device and Attack Relationship Analysis
#
# "Analyze which attack types affect different devices most frequently."

# %%
query = """
SELECT "Device Information" AS device_affected,
       "Traffic Type" AS attack_type,
       COUNT(*) AS attack_count
FROM cyber_threats
GROUP BY "Device Information", "Traffic Type"
ORDER BY attack_count DESC;
"""
pd.read_sql(query, conn)
# Out:
#                                          device_affected attack_type  \
# 0      Mozilla/5.0 (compatible; MSIE 6.0; Windows CE;...         FTP
# 1      Mozilla/5.0 (compatible; MSIE 5.0; Windows CE;...         FTP
# 2      Mozilla/5.0 (compatible; MSIE 6.0; Windows NT ...        HTTP
# 3      Mozilla/5.0 (compatible; MSIE 7.0; Windows 98;...         DNS
# 4      Mozilla/5.0 (compatible; MSIE 7.0; Windows NT ...         FTP
# ...                                                  ...         ...
# 33059  Opera/9.99.(X11; Linux x86_64; raj-IN) Presto/...         DNS
# 33060  Opera/9.99.(X11; Linux x86_64; te-IN) Presto/2...        HTTP
# 33061  Opera/9.99.(X11; Linux x86_64; ti-ER) Presto/2...         FTP
# 33062  Opera/9.99.(X11; Linux x86_64; wal-ET) Presto/...        HTTP
# 33063  Opera/9.99.(X11; Linux x86_64; zh-TW) Presto/2...        HTTP
#
#        attack_count
# 0                15
# 1                14
# 2                14
# 3                14
# 4                14
# ...             ...
# 33059             1
# 33060             1
# 33061             1
# 33062             1
# 33063             1
#
# [33064 rows x 3 columns]

# %% [markdown]
# ## Prompt Used for Detection Effectiveness Analysis
#
# "Analyze how many cyber attacks were detected by each detection mechanism."

# %%
query = """
SELECT "IDS/IPS Alerts" AS detected_by, COUNT(*) AS detected_attacks
FROM cyber_threats
GROUP BY "IDS/IPS Alerts"
ORDER BY detected_attacks DESC;
"""
pd.read_sql(query, conn)
# Out:
#   detected_by  detected_attacks
# 0        None             20050
# 1  Alert Data             19950

# %% [markdown]
# ## Prompt Used for Average Impact Analysis
#
# "Calculate the average numeric impact level for each attack type."

# %%
query = """
SELECT "Traffic Type" AS attack_type,
       ROUND(AVG(impact_level_numeric), 2) AS avg_impact
FROM cyber_threats
GROUP BY "Traffic Type"
ORDER BY avg_impact DESC;
"""
pd.read_sql(query, conn)
# Out:
#   attack_type  avg_impact
# 0        HTTP        2.01
# 1         FTP        2.01
# 2         DNS        2.00

# %% [markdown]
# ## Prompt Used for Operating System Risk Analysis
#
# "Identify which operating systems are most frequently targeted by cyber attacks."

# %%
query = """
SELECT "Device Information" AS operating_system, COUNT(*) AS total_attacks
FROM cyber_threats
GROUP BY "Device Information"
ORDER BY total_attacks DESC;
"""
pd.read_sql(query, conn)
# Out:
#                                         operating_system  total_attacks
# 0      Mozilla/5.0 (compatible; MSIE 6.0; Windows NT ...             35
# 1      Mozilla/5.0 (compatible; MSIE 5.0; Windows 98;...             34
# 2      Mozilla/5.0 (compatible; MSIE 6.0; Windows CE;...             33
# 3      Mozilla/5.0 (compatible; MSIE 7.0; Windows NT ...             31
# 4      Mozilla/5.0 (compatible; MSIE 5.0; Windows NT ...             31
# ...                                                  ...            ...
# 32099  Mozilla/5.0 (Android 1.0; Mobile; rv:42.0) Gec...              1
# 32100  Mozilla/5.0 (Android 1.0; Mobile; rv:40.0) Gec...              1
# 32101  Mozilla/5.0 (Android 1.0; Mobile; rv:37.0) Gec...              1
# 32102  Mozilla/5.0 (Android 1.0; Mobile; rv:19.0) Gec...              1
# 32103  Mozilla/5.0 (Android 1.0; Mobile; rv:14.0) Gec...              1
#
# [32104 rows x 2 columns]

# %% [markdown]
# ## Prompt Used for Attack Outcome Ratio Analysis
#
# "Calculate the ratio of blocked to successful cyber attacks."

# %%
query = """
SELECT "Action Taken" AS status, COUNT(*) AS count
FROM cyber_threats
GROUP BY "Action Taken";
"""
pd.read_sql(query, conn)
# Out:
#     status  count
# 0  Blocked  13529
# 1  Ignored  13276
# 2   Logged  13195

# %% [markdown]
# ## SQL Task Explanation
#
# This SQL analysis demonstrates the use of SELECT, WHERE, GROUP BY, ORDER BY,
# aggregate functions, and subqueries on a cybersecurity dataset.
# The insights derived help identify attack patterns, severity distribution,
# geographical risks, and affected systems.

# %% [markdown]
# ## Prompting Declaration
#
# This SQL task was completed using AI-based prompting.
# All SQL queries and analysis steps were executed based on structured prompts
# documented in this notebook.
